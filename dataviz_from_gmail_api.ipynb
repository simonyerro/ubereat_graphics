# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# %%
creds = None
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('gmail', 'v1', credentials=creds)

# %%
#     # Call the Gmail API
#     results = service.users().messages().list(userId='me', q='from:uber.france@uber.com subject:commande').execute()
#     messages = results.get('messages', [])

#     if not messages:
#         print('No messages found.')
#     else:
#         print('messages:')
#         for i, message in enumerate(messages):
#             print(message['id'])
#             messages[i] = service.users().messages().get(userId='me', id=message['id']).execute()
# Out:
# messages:
# 177ba3bf420144e7
# 177b2af566e64703
# 17792d961539d6e9
# 17792a23e11a38b0
# 17786a0b17e9f2dc
# 1776e6a35c5c61c0
# 1774920a2c058fc2
# 17748e94912e4d29
# 17726691f4392908
# 17716c7d8c0b72a8
# 176fc056fe29e174
# 176fbce490ab33e5
# 176ba7dd696a6d12
# 176b380c9581f3fc
# 1768f827820dbc5b
# 1768753a91e802ad
# 17681b511f3d84ae
# 17677efff576f187
# 1765be16f1f2e0bb
# 1765186872f2149b
# 176239867ffac51c
# 1760451b0ea5ac59
# 175be0d566d4a01a
# 1758e6ea478366f8
# 175807ecbaa1eca7
# 1757b7c71930b01a
# 1755c7cc1b47a6cb
# 17528c588104aac4
# 1751469051ca3152
# 174f02ad6aafa655
# 174d0d97fb8a7fd7
# 174c773e853adbfb
# 174a82569d8178af
# 1748ec1bdb4123c7
# 174893c8b0dc5e87
# 17468731ed56335a
# 1745016be079b1a4
# 17431dcb45cb429e
# 1741bbe2ef35e82e
# 174073777fe6e9ea
# 173f8b0c79763c70
# 173e97a2b8694802
# 173dda59a00725b9
# 173ce0ade2f13b77
# 173b4dc589d0375f
# 1739a1f5655197ca
# 17378429522d57bf
# 173780b405065ea6
# 1736c4254716c6c6
# 17352f2e3deda484
# 173166ef4f15fd6f
# 1730c0fa2ee7403f
# 17309429949f65a2
# 172fff1dea496d5c
# 172c2b766046905c
# 172c2800b4b48cc8
# 172a341a56fede1a
# 172a30a3c17723bd
# 1727a1644063a50a
# 1723e4b149123731
# 1722ea69e0648927
# 17217f4f9324dc1b
# 172057e8fc4443ca
# 171c7a454731fb30
# 171a3978e6261462
# 1718495042aeb195
# 1717f58a5b61ed71
# 1717f572908f2766
# 1716b08097b32991
# 1713c6eb7751771c
# 1713c6a9cba46bf6
# 1713243557af09c4
# 171320c278257cfd
# 1712d589ed230946
# 17121b00c42e4f19
# 17113201d6f28504
# 170f9c8b7d31cb98
# 170db0f0a5d86726
# 170d60092fbfa8f0
# 170b6ef6230e4c1c
# 1709cda3a802a38a
# 16ef2991323eb1e2
# 16ef061c0f528622

# %%
messages[0]
# Out:
# {'id': '177ba3bf420144e7',
#  'threadId': '177ba3bf420144e7',
#  'labelIds': ['CATEGORY_UPDATES', 'INBOX'],
#  'snippet': 'Total 15,08 € 19 février 2021 Merci d&#39;avoir passé commande, Simon Voici votre facture pour Subway® - Tolbiac. Total 15,08 € 1 Menu SUB30® Poulet(3) Teriyaki 11,90 € Pain au choix Pain avoine et',
#  'payload': {'partId': '',
#   'mimeType': 'text/html',
#   'filename': '',
#   'headers': [{'name': 'Delivered-To', 'value': 'yerrosimon1@gmail.com'},
#    {'name': 'Received',
#     'value': 'by 2002:a54:3d0f:0:0:0:0:0 with SMTP id x15csp8453938ecp;        Fri, 19 Feb 2021 04:20:27 -0800 (PST)'},
#    {'name': 'X-Google-Smtp-Source',
#     'value': 'ABdhPJwxckjlISZmXfs5Ve7no7V1j/ohPd+3h4Yo+PRU5bqjnyCs9KhEWswyVa1Xj9z4TJHm79dT'},
#    {'name': 'X-Received',
#     'value': 'by 2002:aca:1708:: with SMTP id j8mr6217115oii.29.1613737227456;        Fri, 19 Feb 2021 04:20:27 -0800 (PST)'},
#    {'name': 'ARC-Seal',
#     'value': 'i=1; a=rsa-sha256; t=1613737227; cv=none;        d=google.com; s=arc-20160816;        b=XPKCkZvFtSqeH0fegMcRv3sD/NAOeAiIPPOedm51TNg097whUvnAmFdknf66H+RaTq         LtWW9VRhpVTXA76ZGR/1ZaPL/tRDi0NpoUs8qbvnnL7A6Xg0TFp/0RsqiVD4yHN2huR+         EM2wmJDe3HionHv14qjX9IveUzxWm7C1FoTqfyWCO57WZx+/MHOoVgPbnHBcsnYP39Aq         9J3B5a/9i8vnH+f5j1Q3HhWo6vE+LhSfSbKhZcrYs0AUUZ7re1eDUU4hZmSyEVc6HjcH         yU6L0D1aMu4slFJbsJJtIDREpS0cKKs0dMkRYOwmJfPZcFObznAPCbBp9H+u1iNAJvKT         dMlg=='},
#    {'name': 'ARC-Message-Signature',
#     'value': 'i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=date:message-id:subject:to:from:content-transfer-encoding         :mime-version:dkim-signature:dkim-signature;        bh=/DfOdz/kure3TRF4jlhIWMCfmlMLWA5QGlUN1xY8Hns=;        b=O5L+s58y3/X0E2hBG0v5FMLGdhxVYrQFY7+91q2TxpE4Wpq1cWJ8/NZIXYVQDxXRqQ         24T3jQFBY1UmV3jqTlf1TzvZ7p7jjqh3Kpd3t60naaQMDaLzg+DoXp3yZoSDbqc48lug         TIgTmwzuy5y/0uKvzlV9cTGh9r5gY7gILFYWFkaheA7XGm8a8ZCpu3OgR8f0vsEqiXvF         jOZ2k82tJ5SxPdH7eYP7S+m8zcawlTCIi0ilzMZ74+onAztcXNzh76+yjE+DqW1V3cnY         JGZlScuFZeuTI+Nf2uLpCuj+d+rxIkOCZMib5YSCy/Edfh20beSq0kbfOdbFDF/4wK6X         xcoA=='},
#    {'name': 'ARC-Authentication-Results',
#     'value': 'i=1; mx.google.com;       dkim=pass header.i=@uber.com header.s=s1 header.b=C26hOnQU;       dkim=pass header.i=@sendgrid.info header.s=smtpapi header.b=gWbzfOJH;       spf=pass (google.com: domain of bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com designates 167.89.42.46 as permitted sender) smtp.mailfrom="bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com";       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=uber.com'},
#    {'name': 'Return-Path',
#     'value': '<bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com>'},
#    {'name': 'Received',
#     'value': 'from o23.email.uber.com (o23.email.uber.com. [167.89.42.46])        by mx.google.com with ESMTPS id w9si4909929ott.106.2021.02.19.04.20.27        for <yerrosimon1@gmail.com>        (version=TLS1_2 cipher=ECDHE-ECDSA-AES128-GCM-SHA256 bits=128/128);        Fri, 19 Feb 2021 04:20:27 -0800 (PST)'},
#    {'name': 'Received-SPF',
#     'value': 'pass (google.com: domain of bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com designates 167.89.42.46 as permitted sender) client-ip=167.89.42.46;'},
#    {'name': 'Authentication-Results',
#     'value': 'mx.google.com;       dkim=pass header.i=@uber.com header.s=s1 header.b=C26hOnQU;       dkim=pass header.i=@sendgrid.info header.s=smtpapi header.b=gWbzfOJH;       spf=pass (google.com: domain of bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com designates 167.89.42.46 as permitted sender) smtp.mailfrom="bounces+13641-45c3-yerrosimon1=gmail.com@em.uber.com";       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=uber.com'},
#    {'name': 'DKIM-Signature',
#     'value': 'v=1; a=rsa-sha256; c=relaxed/relaxed; d=uber.com; h=mime-version:content-transfer-encoding:from:to:subject:content-type; s=s1; bh=/DfOdz/kure3TRF4jlhIWMCfmlMLWA5QGlUN1xY8Hns=; b=C26hOnQ U6Y0MCRV3+2nXp5kU9o0yW5woOEVdsgP4SsKdJM+XFFVv6xdEsWb4MGBLdph5xHi SXuCo9c9OqTuJFxWIxtv1Ta7Ycibp2TAT7/0bFex28NezxJTm2jDu3z/PUb1H6gf c5TuPx6EvZNep+OadeMAFi/F9Ch/dXmLjjIk='},
#    {'name': 'DKIM-Signature',
#     'value': 'v=1; a=rsa-sha256; c=relaxed/relaxed; d=sendgrid.info; h=mime-version:content-transfer-encoding:from:to:subject:content-type:x-feedback-id; s=smtpapi; bh=/DfOdz/kure3TRF4jlhIWMCfmlMLWA5QGlUN1xY8Hns=; b=gW bzfOJHpwI4Y8XH5nDGwDhsWOTkqA4sNFRM0fACuAkceNvGav8zxQLXmIwa8tkcZj ui6rjQqVfcEp6ld3AGHmgRScIiQoBCmmXHSvJBHCA6nJRyM1iqlNeakP8GADvH5o NUej124ffMEvYKWMwzYlE/KhtDOoa23qcvsXOMeXY='},
#    {'name': 'Received',
#     'value': 'by filter2715p1mdw1.sendgrid.net with SMTP id filter2715p1mdw1-28324-602FAD0A-2B        2021-02-19 12:20:26.729269165 +0000 UTC m=+132947.863948681'},
#    {'name': 'Received',
#     'value': 'from localhost (unknown) by geopod-ismtpd-4-0 (SG) with ESMTP id hmhUqiQaTzKoA8NLgtHm9w for <yerrosimon1@gmail.com>; Fri, 19 Feb 2021 12:20:26.487 +0000 (UTC)'},
#    {'name': 'MIME-Version', 'value': '1.0'},
#    {'name': 'Content-Transfer-Encoding', 'value': 'quoted-printable'},
#    {'name': 'From', 'value': '"Reçu Uber" <uber.france@uber.com>'},
#    {'name': 'To', 'value': '<yerrosimon1@gmail.com>'},
#    {'name': 'Subject',
#     'value': 'Votre commande de vendredi après-midi avec Uber\xa0Eats'},
#    {'name': 'Message-Id',
#     'value': '<ccbd51ad-35dc-5d15-b26a-eb51fe33e138@mail.uber.com>'},
#    {'name': 'X-Uber-Id', 'value': 'ccbd51ad-35dc-5d15-b26a-eb51fe33e138'},
#    {'name': 'Content-Type', 'value': 'text/html; charset=utf-8'},
#    {'name': 'Date', 'value': 'Fri, 19 Feb 2021 12:20:26 +0000 (UTC)'},
